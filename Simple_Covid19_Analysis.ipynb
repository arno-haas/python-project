# %%
import pandas as pd

carebeds = pd.read_csv('https://raw.githubusercontent.com/arno-haas/python-project/master/IBAuslastung.csv')
carebeds.info()
carebeds.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 1 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   time;Belegung Intensivbetten in %;Timestamp  36 non-null     object
# dtypes: object(1)
# memory usage: 416.0+ bytes
#    time;Belegung Intensivbetten in %;Timestamp
# 0            01.04.2020;21;2020-05-06T09:30:00
# 1            02.04.2020;23;2020-05-06T09:30:00
# 2            03.04.2020;26;2020-05-06T09:30:00
# 3            04.04.2020;25;2020-05-06T09:30:00
# 4            05.04.2020;24;2020-05-06T09:30:00
# 5            06.04.2020;24;2020-05-06T09:30:00
# 6            07.04.2020;21;2020-05-06T09:30:00
# 7            08.04.2020;21;2020-05-06T09:30:00
# 8            09.04.2020;21;2020-05-06T09:30:00
# 9            10.04.2020;21;2020-05-06T09:30:00
# 10           11.04.2020;22;2020-05-06T09:30:00
# ...
